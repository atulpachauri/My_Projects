# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# Perform data exploration over iris dataset
iris=pd.read_csv("C:/Users/Codenester/Downloads/data/iris.csv")

# %%
iris.head()
# Out:
#   Species  SepalLength  SepalWidth  PetalLength  PetalWidth
# 0  Setosa           50          33           14           2
# 1  Setosa           46          34           14           3
# 2  Setosa           46          36           10           2
# 3  Setosa           51          33           17           5
# 4  Setosa           55          35           13           2

# %%
iris.tail()
# Out:
#        Species  SepalLength  SepalWidth  PetalLength  PetalWidth
# 145  Virginica           64          27           53          19
# 146  Virginica           68          30           55          21
# 147  Virginica           57          25           50          20
# 148  Virginica           58          28           51          24
# 149  Virginica           63          33           60          25

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris[iris['PetalWidth']>20]
# Out:
#        Species  SepalLength  SepalWidth  PetalLength  PetalWidth
# 100  Virginica           64          28           56          22
# 101  Virginica           67          31           56          24
# 103  Virginica           69          31           51          23
# 107  Virginica           68          32           59          23
# 108  Virginica           62          34           54          23
# 109  Virginica           77          38           67          22
# 110  Virginica           67          33           57          25
# 111  Virginica           76          30           66          21
# 113  Virginica           67          30           52          23
# 116  Virginica           64          32           53          23
# 118  Virginica           67          33           57          21
# 124  Virginica           64          28           56          21
# 126  Virginica           77          30           61          23
# ...

# %%
iris[iris['PetalLength']<20]
# Out:
#    Species  SepalLength  SepalWidth  PetalLength  PetalWidth
# 0   Setosa           50          33           14           2
# 1   Setosa           46          34           14           3
# 2   Setosa           46          36           10           2
# 3   Setosa           51          33           17           5
# 4   Setosa           55          35           13           2
# 5   Setosa           48          31           16           2
# 6   Setosa           52          34           14           2
# 7   Setosa           49          36           14           1
# 8   Setosa           44          32           13           2
# 9   Setosa           50          35           16           6
# 10  Setosa           44          30           13           2
# 11  Setosa           47          32           16           2
# 12  Setosa           48          30           14           3
# 13  Setosa           51          38           16           2
# ...

# %%
iris[iris['SepalLength']>70]
# Out:
#        Species  SepalLength  SepalWidth  PetalLength  PetalWidth
# 109  Virginica           77          38           67          22
# 111  Virginica           76          30           66          21
# 117  Virginica           79          38           64          20
# 119  Virginica           77          28           67          20
# 121  Virginica           72          32           60          18
# 126  Virginica           77          30           61          23
# 129  Virginica           72          30           58          16
# 130  Virginica           71          30           59          21
# 134  Virginica           77          26           69          23
# 137  Virginica           74          28           61          19
# 139  Virginica           73          29           63          18
# 143  Virginica           72          36           61          25

# %%
iris[iris['SepalWidth']>40]
# Out:
#    Species  SepalLength  SepalWidth  PetalLength  PetalWidth
# 24  Setosa           57          44           15           4
# 27  Setosa           52          41           15           1
# 28  Setosa           55          42           14           2

# %%
# Petal length of Species
sns.barplot(x='Species',y='PetalLength',data=iris,hue="Species")
plt.show()

# %%
# Petal Length and Petal Width of deffetent Species
sns.scatterplot(x='PetalLength',y='PetalWidth',data=iris,hue="Species")
plt.show()

# %%
# Sepal Length and Sepal Width of deffetent Species
sns.scatterplot(x='SepalLength',y='SepalWidth',data=iris,hue="Species")
plt.show()

# %%
# Perform Linear Regression
# Model-1(Simple Linear Regression)
y=iris[['SepalLength']]
x=iris[['SepalWidth']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train.head()
# Out:
#      SepalWidth
# 4            35
# 141          30
# 12           30
# 42           30
# 134          26

# %%
y_train.head()
# Out:
#      SepalLength
# 4             55
# 141           65
# 12            48
# 42            48
# 134           77

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 68.47990485659795

# %%
# Model-2(Multi Linear Regression)
y=iris[['SepalLength']]
x=iris[['SepalWidth','PetalLength','PetalWidth']]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
lr2=LinearRegression()

# %%
lr2.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr2.predict(x_test)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 12.767709908288651
